# %% [markdown]
# # Lecture 04

# %% [markdown]
# ## Section 1: Pruning Ratio

# %% [markdown]
# ![](../images/image1.png)

# %% [markdown]
# ![](../images/image2.png)

# %% [markdown]
# ![](../images/image3.png)

# %% [markdown]
# ### Finding Pruning Ratios

# %% [markdown]
# ![](../images/image4.png)

# %% [markdown]
# ![](../images/image5.png)

# %% [markdown]
# ![](../images/image6.png)

# %% [markdown]
# ![](../images/image7.png)

# %% [markdown]
# ![](../images/image8.png)

# %% [markdown]
# ![](../images/image9.png)

# %% [markdown]
# ### Automatic Pruning

# %% [markdown]
# ![](../images/image10.png)

# %% [markdown]
# ![](../images/image11.png)

# %% [markdown]
# ### AMC: AutoML for Model Compression

# %% [markdown]
# ![](../images/image12.png)

# %% [markdown]
# ![](../images/image13.png)

# %% [markdown]
# ![](../images/image14.png)

# %% [markdown]
# ![](../images/image15.png)

# %% [markdown]
# ![](../images/image16.png)

# %% [markdown]
# ![](../images/image17.png)

# %% [markdown]
# ### NetAdapt

# %% [markdown]
# ![](../images/image18.png)

# %% [markdown]
# ![](../images/image19.png)

# %% [markdown]
# ![](../images/image20.png)

# %% [markdown]
# ![](../images/image21.png)

# %% [markdown]
# ![](../images/image22.png)

# %% [markdown]
# ![](../images/image23.png)

# %% [markdown]
# ![](../images/image24.png)

# %% [markdown]
# ![](../images/image25.png)

# %% [markdown]
# ## Section 2: Fine-tuning / Training

# %% [markdown]
# ![](../images/image26.png)

# %% [markdown]
# ### Finetuning Pruned Neural Networks

# %% [markdown]
# ![](../images/image27.png)

# %% [markdown]
# ### Iterative Pruning

# %% [markdown]
# ![](../images/image28.png)

# %% [markdown]
# ### Regularization

# %% [markdown]
# ![](../images/image29.png)

# %% [markdown]
# ![](../images/image30.png)

# %% [markdown]
# ![](../images/image31.png)

# %% [markdown]
# ### System & Hardware Support for Sparsity

# %% [markdown]
# ![](../images/image32.png)

# %% [markdown]
# ### EIE: Weight Sparsity + Activation Sparsity

# %% [markdown]
# ![](../images/image33.png)

# %% [markdown]
# ![](../images/image34.png)

# %% [markdown]
# ![](../images/image35.png)

# %% [markdown]
# ![](../images/image36.png)

# %% [markdown]
# ![](../images/image37.png)

# %% [markdown]
# ![](../images/image38.png)

# %% [markdown]
# ![](../images/image39.png)

# %% [markdown]
# ![](../images/image40.png)

# %% [markdown]
# ![](../images/image41.png)

# %% [markdown]
# ![](../images/image42.png)

# %% [markdown]
# ![](../images/image43.png)

# %% [markdown]
# ![](../images/image44.png)

# %% [markdown]
# ![](../images/image45.png)

# %% [markdown]
# ![](../images/image46.png)

# %% [markdown]
# ![](../images/image47.png)

# %% [markdown]
# ![](../images/image48.png)

# %% [markdown]
# ![](../images/image49.png)

# %% [markdown]
# ![](../images/image50.png)

# %% [markdown]
# ### NVIDIA Tensor Core: M:N Weight Sparsity

# %% [markdown]
# ![](../images/image51.png)

# %% [markdown]
# ![](../images/image52.png)

# %% [markdown]
# ![](../images/image53.png)

# %% [markdown]
# ![](../images/image54.png)

# %% [markdown]
# ![](../images/image55.png)

# %% [markdown]
# ![](../images/image56.png)

# %% [markdown]
# ### Torch Sparse & PointAcc: Activation Sparsity

# %% [markdown]
# ![](../images/image57.png)

# %% [markdown]
# #### > TorchSparse : Sparse Convolution Library

# %% [markdown]
# ![](../images/image58.png)

# %% [markdown]
# ![](../images/image59.png)

# %% [markdown]
# ![](../images/image60.png)

# %% [markdown]
# ![](../images/image61.png)

# %% [markdown]
# ![](../images/image62.png)

# %% [markdown]
# ![](../images/image63.png)

# %% [markdown]
# ![](../images/image64.png)

# %% [markdown]
# ![](../images/image65.png)

# %% [markdown]
# ![](../images/image66.png)

# %% [markdown]
# ![](../images/image67.png)

# %% [markdown]
# ![](../images/image68.png)

# %% [markdown]
# ![](../images/image69.png)

# %% [markdown]
# ![](../images/image70.png)

# %% [markdown]
# ![](../images/image71.png)

# %% [markdown]
# #### > PointAcc: Hardware Accelerator for Sparse Convolution

# %% [markdown]
# ![](../images/image73.png)

# %% [markdown]
# ![](../images/image74.png)

# %% [markdown]
# ![](../images/image75.png)

# %% [markdown]
# ![](../images/image76.png)

# %% [markdown]
# ## Summary

# %% [markdown]
# ![](../images/image77.png)
