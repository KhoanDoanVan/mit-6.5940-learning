# %% [markdown]
# # Lecture 10

# %% [markdown]
# ![](../images/image1.png)

# %% [markdown]
# ![](../images/image2.png)

# %% [markdown]
# ![](../images/image3.png)

# %% [markdown]
# ![](../images/image4.png)

# %% [markdown]
# ![](../images/image5.png)

# %% [markdown]
# ![](../images/image6.png)

# %% [markdown]
# ![](../images/image7.png)

# %% [markdown]
# ![](../images/image8.png)

# %% [markdown]
# ![](../images/image9.png)

# %% [markdown]
# ## Challenges

# %% [markdown]
# ![](../images/image10.png)

# %% [markdown]
# ![](../images/image11.png)

# %% [markdown]
# ![](../images/image12.png)

# %% [markdown]
# ![](../images/image13.png)

# %% [markdown]
# ![](../images/image14.png)

# %% [markdown]
# ![](../images/image15.png)

# %% [markdown]
# ![](../images/image16.png)

# %% [markdown]
# ## Tiny Neural Network Design

# %% [markdown]
# ![](../images/image17.png)

# %% [markdown]
# ![](../images/image18.png)

# %% [markdown]
# ![](../images/image19.png)

# %% [markdown]
# ![](../images/image20.png)

# %% [markdown]
# #### Problem

# %% [markdown]
# ![](../images/image21.png)

# %% [markdown]
# ![](../images/image22.png)

# %% [markdown]
# ![](../images/image23.png)

# %% [markdown]
# ![](../images/image24.png)

# %% [markdown]
# ![](../images/image25.png)

# %% [markdown]
# ![](../images/image26.png)

# %% [markdown]
# ![](../images/image27.png)

# %% [markdown]
# ![](../images/image28.png)

# %% [markdown]
# ### 1. Automated Search Space Optimization

# %% [markdown]
# ![](../images/image29.png)

# %% [markdown]
# ![](../images/image30.png)

# %% [markdown]
# ### 2. Resource-constrained model specialization

# %% [markdown]
# ![](../images/image31.png)

# %% [markdown]
# ![](../images/image32.png)

# %% [markdown]
# ![](../images/image33.png)

# %% [markdown]
# #### Imbalanced Memory Distribution of CNNs

# %% [markdown]
# ![](../images/image34.png)

# %% [markdown]
# ![](../images/image35.png)

# %% [markdown]
# ### 1. Saving Memory with Patch-based Inference

# %% [markdown]
# ![](../images/image36.png)

# %% [markdown]
# ![](../images/image37.png)

# %% [markdown]
# ![](../images/image38.png)

# %% [markdown]
# Problem

# %% [markdown]
# ![](../images/image39.png)

# %% [markdown]
# ![](../images/image40.png)

# %% [markdown]
# ![](../images/image41.png)

# %% [markdown]
# ![](../images/image42.png)

# %% [markdown]
# ### 2. Network Redistribution to Reduce Overhead

# %% [markdown]
# ![](../images/image43.png)

# %% [markdown]
# ### 3. Joint Automated Search for Optimization

# %% [markdown]
# ![](../images/image44.png)

# %% [markdown]
# ![](../images/image45.png)

# %% [markdown]
# ![](../images/image46.png)

# %% [markdown]
# ### Dissecting MCUNetV2 archiecture

# %% [markdown]
# ![](../images/image47.png)

# %% [markdown]
# ![](../images/image48.png)

# %% [markdown]
# ![](../images/image49.png)

# %% [markdown]
# ![](../images/image50.png)

# %% [markdown]
# ![](../images/image51.png)

# %% [markdown]
# ## Applications

# %% [markdown]
# ![](../images/image52.png)

# %% [markdown]
# ![](../images/image53.png)

# %% [markdown]
# ![](../images/image54.png)

# %% [markdown]
# ![](../images/image55.png)

# %% [markdown]
# ![](../images/image56.png)

# %% [markdown]
# ![](../images/image5.png)

# %% [markdown]
# ![](../images/image58.png)

# %% [markdown]
# ![](../images/image59.png)

# %% [markdown]
# ![](../images/image60.png)

# %% [markdown]
# ![](../images/image61.png)

# %% [markdown]
# ![](../images/image62.png)

# %% [markdown]
# ![](../images/image63.png)

# %% [markdown]
# ![](../images/image64.png)

# %% [markdown]
# ![](../images/image65.png)

# %% [markdown]
# ![](../images/image66.png)

# %% [markdown]
# ![](../images/image67.png)

# %% [markdown]
# ![](../images/image68.png)

# %% [markdown]
# ![](../images/image69.png)

# %% [markdown]
# ## Summary

# %% [markdown]
# ![](../images/image70.png)
