# %% [markdown]
# # Lecture 05

# %% [markdown]
# ![](../images/image1.png)

# %% [markdown]
# ![](../images/image2.png)

# %% [markdown]
# ## Numeric Data Types

# %% [markdown]
# ![](../images/image3.png)

# %% [markdown]
# ### Integer

# %% [markdown]
# ![](../images/image4.png)

# %% [markdown]
# ### Fixed-Point Number

# %% [markdown]
# ![](../images/image5.png)

# %% [markdown]
# ### Floating-Point Number

# %% [markdown]
# ![](../images/image6.png)

# %% [markdown]
# ![](../images/image7.png)

# %% [markdown]
# ![](../images/image8.png)

# %% [markdown]
# ![](../images/image9.png)

# %% [markdown]
# ![](../images/image10.png)

# %% [markdown]
# ![](../images/image11.png)

# %% [markdown]
# ![](../images/image12.png)

# %% [markdown]
# ![](../images/image13.png)

# %% [markdown]
# ![](../images/image14.png)

# %% [markdown]
# ![](../images/image15.png)

# %% [markdown]
# ##### Example Floating Point Number

# %% [markdown]
# ![](../images/image16.png)

# %% [markdown]
# ![](../images/image17.png)

# %% [markdown]
# ![](../images/image18.png)

# %% [markdown]
# ### INT4 and FP4

# %% [markdown]
# ![](../images/image19.png)

# %% [markdown]
# ## Quantization

# %% [markdown]
# ![](../images/image20.png)

# %% [markdown]
# ### Neural Network Quantization

# %% [markdown]
# ![](../images/image21.png)

# %% [markdown]
# ![](../images/image22.png)

# %% [markdown]
# ### K-Means-based Weight Quantization

# %% [markdown]
# ![](../images/image23.png)

# %% [markdown]
# ![](../images/image24.png)

# %% [markdown]
# ![](../images/image25.png)

# %% [markdown]
# ![](../images/image35.png)

# %% [markdown]
# ### Linear Quantization

# %% [markdown]
# ![](../images/image36.png)

# %% [markdown]
# ![](../images/image37.png)

# %% [markdown]
# ![](../images/image38.png)

# %% [markdown]
# ![](../images/image39.png)

# %% [markdown]
# ![](../images/image40.png)

# %% [markdown]
# ![](../images/image41.png)

# %% [markdown]
# ![](../images/image42.png)

# %% [markdown]
# ![](../images/image43.png)

# %% [markdown]
# ![](../images/image44.png)

# %% [markdown]
# ![](../images/image45.png)

# %% [markdown]
# ![](../images/image46.png)

# %% [markdown]
# ![](../images/image47.png)

# %% [markdown]
# ![](../images/image48.png)

# %% [markdown]
# ![](../images/image49.png)

# %% [markdown]
# ![](../images/image50.png)

# %% [markdown]
# ![](../images/image51.png)

# %% [markdown]
# ![](../images/image52.png)

# %% [markdown]
# ![](../images/image53.png)

# %% [markdown]
# ![](../images/image54.png)

# %% [markdown]
# ![](../images/image55.png)

# %% [markdown]
# ![](../images/image56.png)

# %% [markdown]
# ### Before Quantization

# %% [markdown]
# ![](../images/image26.png)

# %% [markdown]
# ### After Quantization

# %% [markdown]
# ![](../images/image27.png)

# %% [markdown]
# ![](../images/image28.png)

# %% [markdown]
# ### How many Bits do we need?

# %% [markdown]
# ![](../images/image29.png)

# %% [markdown]
# ### Huffman Coding

# %% [markdown]
# ![](../images/image30.png)

# %% [markdown]
# ### Summary of Deep Compression

# %% [markdown]
# ![](../images/image31.png)

# %% [markdown]
# ### Deep Compression Resulst

# %% [markdown]
# ![](../images/image32.png)

# %% [markdown]
# ### SqueezeNet

# %% [markdown]
# ![](../images/image33.png)

# %% [markdown]
# ![](../images/image34.png)

# %% [markdown]
# ## Summary

# %% [markdown]
# ![](../images/image57.png)
