# %% [markdown]
# # Lecture 09

# %% [markdown]
# ![](../images/image1.png)

# %% [markdown]
# ![](../images/image2.png)

# %% [markdown]
# ## What is KD?

# %% [markdown]
# ![](../images/image3.png)

# %% [markdown]
# ![](../images/image4.png)

# %% [markdown]
# ![](../images/image5.png)

# %% [markdown]
# ![](../images/image6.png)

# %% [markdown]
# ![](../images/image7.png)

# %% [markdown]
# ## What to match

# %% [markdown]
# ![](../images/image8.png)

# %% [markdown]
# #### Output Logits

# %% [markdown]
# ![](../images/image9.png)

# %% [markdown]
# ![](../images/image10.png)

# %% [markdown]
# #### Intermediate weights

# %% [markdown]
# ![](../images/image11.png)

# %% [markdown]
# ![](../images/image12.png)

# %% [markdown]
# ![](../images/image13.png)

# %% [markdown]
# #### Intermediate features

# %% [markdown]
# ![](../images/image14.png)

# %% [markdown]
# ![](../images/image15.png)

# %% [markdown]
# #### Gradients

# %% [markdown]
# ![](../images/image16.png)

# %% [markdown]
# ![](../images/image17.png)

# %% [markdown]
# ![](../images/image18.png)

# %% [markdown]
# ![](../images/image19.png)

# %% [markdown]
# #### Sparsity patterns

# %% [markdown]
# ![](../images/image20.png)

# %% [markdown]
# ![](../images/image21.png)

# %% [markdown]
# #### Relational Information

# %% [markdown]
# ![](../images/image22.png)

# %% [markdown]
# ![](../images/image23.png)

# %% [markdown]
# ![](../images/image24.png)

# %% [markdown]
# ![](../images/image25.png)

# %% [markdown]
# ## Self and Online Distillation

# %% [markdown]
# ![](../images/image26.png)

# %% [markdown]
# ![](../images/image27.png)

# %% [markdown]
# ![](../images/image28.png)

# %% [markdown]
# ![](../images/image29.png)

# %% [markdown]
# ![](../images/image30.png)

# %% [markdown]
# ![](../images/image31.png)

# %% [markdown]
# ![](../images/image32.png)

# %% [markdown]
# ![](../images/image33.png)

# %% [markdown]
# ![](../images/image34.png)

# %% [markdown]
# ![](../images/image35.png)

# %% [markdown]
# ![](../images/image36.png)

# %% [markdown]
# ## Distillation for different task

# %% [markdown]
# ![](../images/image37.png)

# %% [markdown]
# ![](../images/image38.png)

# %% [markdown]
# ![](../images/image39.png)

# %% [markdown]
# ![](../images/image40.png)

# %% [markdown]
# ![](../images/image41.png)

# %% [markdown]
# ![](../images/image42.png)

# %% [markdown]
# ![](../images/image43.png)

# %% [markdown]
# ![](../images/image44.png)

# %% [markdown]
# ![](../images/image45.png)

# %% [markdown]
# ![](../images/image46.png)

# %% [markdown]
# ![](../images/image47.png)

# %% [markdown]
# ![](../images/image48.png)

# %% [markdown]
# ![](../images/image49.png)

# %% [markdown]
# ![](../images/image50.png)

# %% [markdown]
# ![](../images/image51.png)

# %% [markdown]
# ![](../images/image52.png)

# %% [markdown]
# ![](../images/image53.png)

# %% [markdown]
# ![](../images/image54.png)

# %% [markdown]
# ![](../images/image55.png)

# %% [markdown]
# ![](../images/image56.png)

# %% [markdown]
# ![](../images/image57.png)

# %% [markdown]
# ![](../images/image58.png)

# %% [markdown]
# ![](../images/image59.png)

# %% [markdown]
# ![](../images/image60.png)

# %% [markdown]
# ![](../images/image61.png)

# %% [markdown]
# ![](../images/image62.png)

# %% [markdown]
# ![](../images/image63.png)

# %% [markdown]
# ![](../images/image64.png)

# %% [markdown]
# ![](../images/image65.png)

# %% [markdown]
# ## Summary

# %% [markdown]
# ![](../images/image66.png)
