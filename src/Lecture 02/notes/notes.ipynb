# %% [markdown]
# # Lecture 02

# %% [markdown]
# ![](../images/image1.png)

# %% [markdown]
# ![](../images/image2.png)

# %% [markdown]
# ## FC Layer

# %% [markdown]
# ![](../images/image3.png)

# %% [markdown]
# ![](../images/image5.png)

# %% [markdown]
# ## Convolution Layer

# %% [markdown]
# ### 1D Conv

# %% [markdown]
# ![](../images/image6.png)

# %% [markdown]
# ![](../images/image7.png)

# %% [markdown]
# ![](../images/image8.png)

# %% [markdown]
# ![](../images/image9.png)

# %% [markdown]
# ![](../images/image10.png)

# %% [markdown]
# ### 2D Conv

# %% [markdown]
# ![](../images/image11.png)

# %% [markdown]
# ![](../images/image12.png)

# %% [markdown]
# ![](../images/image13.png)

# %% [markdown]
# ## Convolution Layer: Padding

# %% [markdown]
# ![](../images/image14.png)

# %% [markdown]
# ## Convolution Layer: Receptive Field

# %% [markdown]
# ![](../images/image15.png)

# %% [markdown]
# ## Strided Convolution Layer

# %% [markdown]
# ![](../images/image16.png)

# %% [markdown]
# ## Grouped Convolution Layer

# %% [markdown]
# ![](../images/image17.png)

# %% [markdown]
# ## Depthwise Convolution Layer

# %% [markdown]
# ![](../images/image18.png)

# %% [markdown]
# ## Pooling Layer

# %% [markdown]
# Note: No learnable parameters

# %% [markdown]
# ![](../images/image19.png)

# %% [markdown]
# ## Normalization Layer

# %% [markdown]
# ![](../images/image20.png)

# %% [markdown]
# ## Acitvation Function

# %% [markdown]
# ![](../images/image21.png)

# %% [markdown]
# ## Transformer

# %% [markdown]
# ![](../images/image22.png)

# %% [markdown]
# ## Alex Net

# %% [markdown]
# ![](../images/image23.png)

# %% [markdown]
# ## VGG-16

# %% [markdown]
# ![](../images/image24.png)

# %% [markdown]
# ## ResNet-50

# %% [markdown]
# ![](../images/image25.png)

# %% [markdown]
# ## MobileNetV2

# %% [markdown]
# ![](../images/image26.png)

# %% [markdown]
# ## Efficiency of Neural Networks

# %% [markdown]
# ![](../images/image27.png)

# %% [markdown]
# ![](../images/image28.png)

# %% [markdown]
# ![](../images/image29.png)

# %% [markdown]
# ![](../images/image30.png)

# %% [markdown]
# ### Number of Parameters

# %% [markdown]
# ![](../images/image31.png)

# %% [markdown]
# ![](../images/image32.png)

# %% [markdown]
# ![](../images/image33.png)

# %% [markdown]
# ![](../images/image34.png)

# %% [markdown]
# #### Example AlexNet: #Parameters

# %% [markdown]
# ![](../images/image35.png)

# %% [markdown]
# ### Model Size

# %% [markdown]
# ![](../images/image36.png)

# %% [markdown]
# ### Number of Activations

# %% [markdown]
# ![](../images/image37.png)

# %% [markdown]
# ![](../images/image38.png)

# %% [markdown]
# ![](../images/image39.png)

# %% [markdown]
# ![](../images/image40.png)

# %% [markdown]
# ##### Example AlexNet: #Actications

# %% [markdown]
# ![](../images/image41.png)

# %% [markdown]
# ### MAC - Number of Multiply-Accumulate Operations

# %% [markdown]
# ![](../images/image42.png)

# %% [markdown]
# ![](../images/image43.png)

# %% [markdown]
# ![](../images/image44.png)

# %% [markdown]
# ![](../images/image45.png)

# %% [markdown]
# ![](../images/image46.png)

# %% [markdown]
# ##### Example AlexNet: # MACs

# %% [markdown]
# ![](../images/image47.png)

# %% [markdown]
# ### FLOP, FLOPs

# %% [markdown]
# ![](../images/image48.png)

# %% [markdown]
# ### OP, OPs

# %% [markdown]
# ![](../images/image49.png)

# %% [markdown]
# ### Final

# %% [markdown]
# ![](../images/image50.png)
