# %% [markdown]
# # Lecture 06

# %% [markdown]
# ![](../images/image1.png)

# %% [markdown]
# ## Post-Training Quantization

# %% [markdown]
# ![](../images/image2.png)

# %% [markdown]
# ### Topic I: Quantization Granularity

# %% [markdown]
# ![](../images/image3.png)

# %% [markdown]
# ![](../images/image4.png)

# %% [markdown]
# ![](../images/image5.png)

# %% [markdown]
# ### > Per-Tensor Quantization

# %% [markdown]
# ### > Per-Channel Weight Quantization

# %% [markdown]
# ![](../images/image6.png)

# %% [markdown]
# ### > Group Quantizaation

# %% [markdown]
# ![](../images/image7.png)

# %% [markdown]
# ![](../images/image9.png)

# %% [markdown]
# ![](../images/image10.png)

# %% [markdown]
# ![](../images/image11.png)

# %% [markdown]
# ![](../images/image12.png)

# %% [markdown]
# #### VS-Quant: Per-vector Scaled Quantization

# %% [markdown]
# ![](../images/image8.png)

# %% [markdown]
# ### Topic-II: Dynamc Range Clipping

# %% [markdown]
# ![](../images/image13.png)

# %% [markdown]
# #### Linear Quantization on Activations

# %% [markdown]
# ![](../images/image14.png)

# %% [markdown]
# Type 1:

# %% [markdown]
# ![](../images/image15.png)

# %% [markdown]
# Type 2:

# %% [markdown]
# ![](../images/image16.png)

# %% [markdown]
# ![](../images/image17.png)

# %% [markdown]
# ![](../images/image18.png)

# %% [markdown]
# ![](../images/image19.png)

# %% [markdown]
# ![](../images/image20.png)

# %% [markdown]
# ![](../images/image21.png)

# %% [markdown]
# ![](../images/image22.png)

# %% [markdown]
# ### Topic III: Rounding

# %% [markdown]
# ![](../images/image23.png)

# %% [markdown]
# ![](../images/image24.png)

# %% [markdown]
# ![](../images/image25.png)

# %% [markdown]
# ![](../images/image26.png)

# %% [markdown]
# ![](../images/image27.png)

# %% [markdown]
# ![](../images/image28.png)

# %% [markdown]
# ## Quantization-Aware Training

# %% [markdown]
# ![](../images/image29.png)

# %% [markdown]
# ![](../images/image30.png)

# %% [markdown]
# ![](../images/image31.png)

# %% [markdown]
# ![](../images/image32.png)

# %% [markdown]
# ![](../images/image33.png)

# %% [markdown]
# ![](../images/image34.png)

# %% [markdown]
# #### Straight-Through Estimator (STE)

# %% [markdown]
# ![](../images/image35.png)

# %% [markdown]
# ![](../images/image36.png)

# %% [markdown]
# ![](../images/image37.png)

# %% [markdown]
# ![](../images/image38.png)

# %% [markdown]
# ## Binary/Ternary Quantization

# %% [markdown]
# ![](../images/image39.png)

# %% [markdown]
# ![](../images/image40.png)

# %% [markdown]
# ![](../images/image41.png)

# %% [markdown]
# ### Binarization

# %% [markdown]
# ![](../images/image42.png)

# %% [markdown]
# ![](../images/image43.png)

# %% [markdown]
# ![](../images/image44.png)

# %% [markdown]
# ![](../images/image45.png)

# %% [markdown]
# ![](../images/image46.png)

# %% [markdown]
# ![](../images/image47.png)

# %% [markdown]
# ![](../images/image48.png)

# %% [markdown]
# ![](../images/image49.png)

# %% [markdown]
# ![](../images/image50.png)

# %% [markdown]
# ### Ternary Weight Networks (TWN)

# %% [markdown]
# ![](../images/image51.png)

# %% [markdown]
# ### Trained Tenary Quantization (TTQ)

# %% [markdown]
# ![](../images/image52.png)

# %% [markdown]
# ## Mixed-Precision Quantization

# %% [markdown]
# ![](../images/image53.png)

# %% [markdown]
# ### Uniform Quantization

# %% [markdown]
# ![](../images/image54.png)

# %% [markdown]
# ### Mixed_Precision Quantization

# %% [markdown]
# ![](../images/image55.png)

# %% [markdown]
# ### Challenge: Huge Design Space

# %% [markdown]
# ![](../images/image56.png)

# %% [markdown]
# ### Solution: Design Automation

# %% [markdown]
# ![](../images/image57.png)

# %% [markdown]
# ### HAQ

# %% [markdown]
# ![](../images/image58.png)

# %% [markdown]
# ![](../images/image59.png)

# %% [markdown]
# ## Quntization Policy for Edge and Cloud

# %% [markdown]
# ![](../images/image60.png)

# %% [markdown]
# ## Summarry

# %% [markdown]
# ![](../images/image61.png)
